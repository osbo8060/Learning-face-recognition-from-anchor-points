# %%
from facetorch import FaceAnalyzer
from facetorch.analyzer.utilizer import LandmarkDrawerTorch
from omegaconf import OmegaConf
from torch.nn.functional import cosine_similarity
from typing import Dict
import operator
import torchvision
import os
import shutil
import torch
import numpy as np
import pandas as pd
from PIL import Image

# %%
DATASET_PATH = './Curated_Dataset/'
ANCHOR_PATH = './dataset/anchor_points_dataset/'
FACE_PATH = './dataset/face_dataset/'

if os.path.exists(FACE_PATH):
    shutil.rmtree(FACE_PATH)

if os.path.exists(ANCHOR_PATH):
    shutil.rmtree(ANCHOR_PATH)

os.makedirs(FACE_PATH)
os.makedirs(ANCHOR_PATH)

cfg = OmegaConf.load("./gpu.config.yml")

# %%
from scipy.spatial.transform import Rotation as R

def Rotate_Face(pts):
    data = pts[0]

    x = data[0, :]
    y = data[1, :]
    z = data[2, :]

    face_tensor = torch.stack([x, y, z], dim=1).to('cuda:0')
    # Väldigt hustler-lösning, får inte skiten att se bra ut

    sum_vectors = torch.sum(face_tensor, dim=0)
    centroid = sum_vectors / face_tensor.shape[0]
    face_tensor_orgin = (face_tensor - centroid).cpu().numpy()


    P1 = face_tensor_orgin[0]
    P2 = face_tensor_orgin[16]

    y1 = P1[1]
    y2 = P2[1]

    while abs(y1 - y2) > 1:
        r = R.from_euler('z', -0.1, degrees=True)
        face_tensor_orgin =  face_tensor_orgin @ r.as_matrix().T
        P1 = face_tensor_orgin[0]
        P2 = face_tensor_orgin[16]
        y1 = P1[1]
        y2 = P2[1]



    ### VET INTE OM DETTA FUNKAR ###
    z1 = P1[2]
    z2 = P2[2]
    x = face_tensor_orgin[33][0]

    i = 0.1
    if x > 0:
        i = -0.1

    while abs(z1 - z2) > 1:
        r = R.from_euler('y', i, degrees=True)
        face_tensor_orgin =  face_tensor_orgin @ r.as_matrix().T
        P1 = face_tensor_orgin[0]
        P2 = face_tensor_orgin[16]
        z1 = P1[2]
        z2 = P2[2]

    ### VET INTE OM DETTA FUNKAR SLUT ###

    if face_tensor_orgin[25][1] > 0:
        r = R.from_euler('z', 180, degrees=True)
        face_tensor_orgin =  face_tensor_orgin @ r.as_matrix().T
    
    return face_tensor_orgin

def fft_func(arr):
    norm = np.linalg.norm(arr)  # Calculate the L2 norm of the data
    normalized_data = arr / norm
    transformed = np.fft.fftn(normalized_data)

    magnintude = np.abs(transformed)

    transformed_array = np.zeros(shape=(magnintude.shape[0]-1, magnintude.shape[1]))
    for i in range(0,3):
        background_value = magnintude[:,i][0]
        column = magnintude[:,i][1:]

        # column = column / background_value  # Creates infinity values

        transformed_array[:,i] = column


    return transformed_array

def Process_Image(path_img):
    """
    Processes the input image and extracts important features (anchor points).

    Args:
        path_to_image (str): The file path to the image to be processed.

    Returns:
        processed_image: The image after processing 
        anchor_points: A set of key points or features detected in the image (e.g., corners, edges, or other important features).
    """
    analyzer = FaceAnalyzer(cfg.analyzer)
    response = analyzer.run(
        path_image=path_img,
        batch_size=cfg.batch_size,
        return_img_data=cfg.return_img_data,
        include_tensors=cfg.include_tensors,
        fix_img_size=cfg.fix_img_size
    )
    return response

def Save_Processed_Image(response, path):
    pil_image = torchvision.transforms.functional.to_pil_image(response.img)
    pil_image.save(path)
    return 

def Save_Feature_Vector(arr, name, data_fft, data_points):
    arr = Rotate_Face(arr)
    fft = fft_func(arr)
    flat_list = fft.reshape(-1)
    data_fft.loc[len(data_fft)] = flat_list.tolist() + [name]
    data_points.loc[len(data_points)] = arr.reshape(-1).tolist() + [name]

    return

# %%
columns = [f'feature_{i}' for i in range(1, 202)] + ['label']
df_fft = pd.DataFrame(columns=columns)

columns = [f'feature_{i}' for i in range(1, 205)] + ['label']
df_points = pd.DataFrame(columns=columns)
for name in os.listdir(DATASET_PATH):

    temp_path = DATASET_PATH + f'{name}'  
    temp_anchor_path = ANCHOR_PATH + f'{name}'
    temp_face_path = FACE_PATH + f'{name}'

    if os.path.exists(temp_face_path):
        shutil.rmtree(temp_face_path)


    os.makedirs(temp_face_path)
    i = 0
    for image in os.listdir(temp_path):

        # Process original image
        response = Process_Image( temp_path + f'/{image}')
        pts = [face.preds["align"].other["lmk3d"].cpu() for face in response.faces]
        if len(pts) == 1:
            
            Save_Processed_Image(response, f'{temp_face_path}/{name}{i}.jpg')
            Save_Feature_Vector(pts, name, df_fft, df_points)
            i += 1

    if os.path.isdir(temp_face_path) and len(os.listdir(temp_face_path)) == 0:
        os.rmdir(temp_face_path)
    
    df_fft.to_csv(ANCHOR_PATH + 'processed_data_fft.csv', index=False)
    df_points.to_csv(ANCHOR_PATH + 'data_points.csv', index=False)
# Out:
# {"asctime": "2024-10-23 01:29:31,674", "levelname": "INFO", "message": "Initializing FaceAnalyzer", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:29:31,675", "levelname": "INFO", "message": "Initializing BaseReader", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:29:32,479", "levelname": "INFO", "message": "Initializing FaceDetector", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:29:33,130", "levelname": "INFO", "message": "Initializing FaceUnifier", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:29:33,145", "levelname": "INFO", "message": "Initializing FacePredictor objects", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:29:33,146", "levelname": "INFO", "message": "Initializing FacePredictor embed", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:29:33,418", "levelname": "INFO", "message": "Initializing FacePredictor verify", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:29:36,586", "levelname": "INFO", "message": "Initializing FacePredictor au", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:29:37,532", "levelname": "INFO", "message": "Initializing FacePredictor va", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:29:37,601", "levelname": "INFO", "message": "Initializing FacePredictor align", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:29:38,014", "levelname": "INFO", "message": "Initializing BaseUtilizer objects", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:29:38,016", "levelname": "INFO", "message": "Initializing BaseUtilizer align", "taskName": "Task-3"}
# c:\Users\danie\anaconda3\envs\FaceTorch\Lib\site-packages\facetorch\analyzer\utilizer\align.py:40: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.meta = torch.load(self.downloader_meta.path_local)
# {"asctime": "2024-10-23 01:29:38,176", "levelname": "INFO", "message": "Initializing BaseUtilizer draw_boxes", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:29:38,178", "levelname": "INFO", "message": "Initializing BaseUtilizer draw_landmarks", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:29:38,180", "levelname": "INFO", "message": "Running FaceAnalyzer", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:29:38,181", "levelname": "INFO", "message": "Reading image", "taskName": "Task-3", "input": "./Curated_Dataset/Abdullah_Gul/Abdullah_Gul_0001.jpg"}
# {"asctime": "2024-10-23 01:29:38,312", "levelname": "INFO", "message": "Detecting faces", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:29:39,595", "levelname": "INFO", "message": "Number of faces: 1", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:29:39,595", "levelname": "INFO", "message": "Unifying faces", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:29:39,618", "levelname": "INFO", "message": "Predicting facial features", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:29:39,619", "levelname": "INFO", "message": "Running FacePredictor: embed", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:29:39,879", "levelname": "INFO", "message": "Running FacePredictor: verify", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:29:55,557", "levelname": "INFO", "message": "Running FacePredictor: au", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:29:56,244", "levelname": "INFO", "message": "Running FacePredictor: va", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:29:56,275", "levelname": "INFO", "message": "Running FacePredictor: align", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:29:56,597", "levelname": "INFO", "message": "Utilizing facial features", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:29:56,598", "levelname": "INFO", "message": "Running BaseUtilizer: align", "taskName": "Task-3"}
# c:\Users\danie\anaconda3\envs\FaceTorch\Lib\site-packages\facetorch\analyzer\utilizer\align.py:223: UserWarning: Using torch.cross without specifying the dim arg is deprecated.
# Please either pass the dim explicitly or simply use torch.linalg.cross.
# The default value of dim will change to agree with that of linalg.cross in a future release. (Triggered internally at C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\Cross.cpp:66.)
#   r3 = torch.cross(r1, r2)
# {"asctime": "2024-10-23 01:29:56,638", "levelname": "INFO", "message": "Running BaseUtilizer: draw_boxes", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:29:56,692", "levelname": "INFO", "message": "Running BaseUtilizer: draw_landmarks", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:29:56,828", "levelname": "INFO", "message": "Initializing FaceAnalyzer", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:29:56,829", "levelname": "INFO", "message": "Initializing BaseReader", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:29:56,842", "levelname": "INFO", "message": "Initializing FaceDetector", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:29:57,253", "levelname": "INFO", "message": "Initializing FaceUnifier", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:29:57,266", "levelname": "INFO", "message": "Initializing FacePredictor objects", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:29:57,267", "levelname": "INFO", "message": "Initializing FacePredictor embed", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:29:57,618", "levelname": "INFO", "message": "Initializing FacePredictor verify", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:30:02,403", "levelname": "INFO", "message": "Initializing FacePredictor au", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:30:03,391", "levelname": "INFO", "message": "Initializing FacePredictor va", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:30:03,467", "levelname": "INFO", "message": "Initializing FacePredictor align", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:30:03,794", "levelname": "INFO", "message": "Initializing BaseUtilizer objects", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:30:03,794", "levelname": "INFO", "message": "Initializing BaseUtilizer align", "taskName": "Task-3"}
# c:\Users\danie\anaconda3\envs\FaceTorch\Lib\site-packages\facetorch\analyzer\utilizer\align.py:40: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.meta = torch.load(self.downloader_meta.path_local)
# {"asctime": "2024-10-23 01:30:03,834", "levelname": "INFO", "message": "Initializing BaseUtilizer draw_boxes", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:30:03,837", "levelname": "INFO", "message": "Initializing BaseUtilizer draw_landmarks", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:30:03,839", "levelname": "INFO", "message": "Running FaceAnalyzer", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:30:03,839", "levelname": "INFO", "message": "Reading image", "taskName": "Task-3", "input": "./Curated_Dataset/Abdullah_Gul/Abdullah_Gul_0001_hor_flipped.jpg"}
# {"asctime": "2024-10-23 01:30:03,865", "levelname": "INFO", "message": "Detecting faces", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:30:04,070", "levelname": "INFO", "message": "Number of faces: 1", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:30:04,071", "levelname": "INFO", "message": "Unifying faces", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:30:04,091", "levelname": "INFO", "message": "Predicting facial features", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:30:04,092", "levelname": "INFO", "message": "Running FacePredictor: embed", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:30:04,216", "levelname": "INFO", "message": "Running FacePredictor: verify", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:30:18,238", "levelname": "INFO", "message": "Running FacePredictor: au", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:30:18,835", "levelname": "INFO", "message": "Running FacePredictor: va", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:30:18,851", "levelname": "INFO", "message": "Running FacePredictor: align", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:30:19,030", "levelname": "INFO", "message": "Utilizing facial features", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:30:19,031", "levelname": "INFO", "message": "Running BaseUtilizer: align", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:30:19,035", "levelname": "INFO", "message": "Running BaseUtilizer: draw_boxes", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:30:19,037", "levelname": "INFO", "message": "Running BaseUtilizer: draw_landmarks", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:30:19,169", "levelname": "INFO", "message": "Initializing FaceAnalyzer", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:30:19,169", "levelname": "INFO", "message": "Initializing BaseReader", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:30:19,184", "levelname": "INFO", "message": "Initializing FaceDetector", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:30:19,611", "levelname": "INFO", "message": "Initializing FaceUnifier", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:30:19,627", "levelname": "INFO", "message": "Initializing FacePredictor objects", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:30:19,628", "levelname": "INFO", "message": "Initializing FacePredictor embed", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:30:19,983", "levelname": "INFO", "message": "Initializing FacePredictor verify", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:30:24,842", "levelname": "INFO", "message": "Initializing FacePredictor au", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:30:25,871", "levelname": "INFO", "message": "Initializing FacePredictor va", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:30:25,943", "levelname": "INFO", "message": "Initializing FacePredictor align", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:30:26,260", "levelname": "INFO", "message": "Initializing BaseUtilizer objects", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:30:26,261", "levelname": "INFO", "message": "Initializing BaseUtilizer align", "taskName": "Task-3"}
# c:\Users\danie\anaconda3\envs\FaceTorch\Lib\site-packages\facetorch\analyzer\utilizer\align.py:40: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.meta = torch.load(self.downloader_meta.path_local)
# {"asctime": "2024-10-23 01:30:26,307", "levelname": "INFO", "message": "Initializing BaseUtilizer draw_boxes", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:30:26,309", "levelname": "INFO", "message": "Initializing BaseUtilizer draw_landmarks", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:30:26,311", "levelname": "INFO", "message": "Running FaceAnalyzer", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:30:26,311", "levelname": "INFO", "message": "Reading image", "taskName": "Task-3", "input": "./Curated_Dataset/Abdullah_Gul/Abdullah_Gul_0002.jpg"}
# {"asctime": "2024-10-23 01:30:26,316", "levelname": "INFO", "message": "Detecting faces", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:30:26,557", "levelname": "INFO", "message": "Number of faces: 1", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:30:26,557", "levelname": "INFO", "message": "Unifying faces", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:30:26,558", "levelname": "INFO", "message": "Predicting facial features", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:30:26,559", "levelname": "INFO", "message": "Running FacePredictor: embed", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:30:26,691", "levelname": "INFO", "message": "Running FacePredictor: verify", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:30:41,453", "levelname": "INFO", "message": "Running FacePredictor: au", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:30:42,045", "levelname": "INFO", "message": "Running FacePredictor: va", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:30:42,064", "levelname": "INFO", "message": "Running FacePredictor: align", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:30:42,214", "levelname": "INFO", "message": "Utilizing facial features", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:30:42,215", "levelname": "INFO", "message": "Running BaseUtilizer: align", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:30:42,219", "levelname": "INFO", "message": "Running BaseUtilizer: draw_boxes", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:30:42,221", "levelname": "INFO", "message": "Running BaseUtilizer: draw_landmarks", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:30:42,382", "levelname": "INFO", "message": "Initializing FaceAnalyzer", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:30:42,383", "levelname": "INFO", "message": "Initializing BaseReader", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:30:42,395", "levelname": "INFO", "message": "Initializing FaceDetector", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:30:42,788", "levelname": "INFO", "message": "Initializing FaceUnifier", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:30:42,800", "levelname": "INFO", "message": "Initializing FacePredictor objects", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:30:42,801", "levelname": "INFO", "message": "Initializing FacePredictor embed", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:30:43,146", "levelname": "INFO", "message": "Initializing FacePredictor verify", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:30:48,044", "levelname": "INFO", "message": "Initializing FacePredictor au", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:30:49,059", "levelname": "INFO", "message": "Initializing FacePredictor va", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:30:49,131", "levelname": "INFO", "message": "Initializing FacePredictor align", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:30:49,453", "levelname": "INFO", "message": "Initializing BaseUtilizer objects", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:30:49,453", "levelname": "INFO", "message": "Initializing BaseUtilizer align", "taskName": "Task-3"}
# c:\Users\danie\anaconda3\envs\FaceTorch\Lib\site-packages\facetorch\analyzer\utilizer\align.py:40: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.meta = torch.load(self.downloader_meta.path_local)
# {"asctime": "2024-10-23 01:30:49,498", "levelname": "INFO", "message": "Initializing BaseUtilizer draw_boxes", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:30:49,500", "levelname": "INFO", "message": "Initializing BaseUtilizer draw_landmarks", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:30:49,502", "levelname": "INFO", "message": "Running FaceAnalyzer", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:30:49,502", "levelname": "INFO", "message": "Reading image", "taskName": "Task-3", "input": "./Curated_Dataset/Abdullah_Gul/Abdullah_Gul_0002_hor_flipped.jpg"}
# {"asctime": "2024-10-23 01:30:49,533", "levelname": "INFO", "message": "Detecting faces", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:30:49,795", "levelname": "INFO", "message": "Number of faces: 1", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:30:49,796", "levelname": "INFO", "message": "Unifying faces", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:30:49,801", "levelname": "INFO", "message": "Predicting facial features", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:30:49,801", "levelname": "INFO", "message": "Running FacePredictor: embed", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:30:49,927", "levelname": "INFO", "message": "Running FacePredictor: verify", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:31:07,905", "levelname": "INFO", "message": "Running FacePredictor: au", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:31:08,569", "levelname": "INFO", "message": "Running FacePredictor: va", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:31:08,586", "levelname": "INFO", "message": "Running FacePredictor: align", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:31:08,738", "levelname": "INFO", "message": "Utilizing facial features", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:31:08,738", "levelname": "INFO", "message": "Running BaseUtilizer: align", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:31:08,746", "levelname": "INFO", "message": "Running BaseUtilizer: draw_boxes", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:31:08,749", "levelname": "INFO", "message": "Running BaseUtilizer: draw_landmarks", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:31:08,865", "levelname": "INFO", "message": "Initializing FaceAnalyzer", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:31:08,865", "levelname": "INFO", "message": "Initializing BaseReader", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:31:08,878", "levelname": "INFO", "message": "Initializing FaceDetector", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:31:09,250", "levelname": "INFO", "message": "Initializing FaceUnifier", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:31:09,263", "levelname": "INFO", "message": "Initializing FacePredictor objects", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:31:09,264", "levelname": "INFO", "message": "Initializing FacePredictor embed", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:31:09,708", "levelname": "INFO", "message": "Initializing FacePredictor verify", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:31:12,960", "levelname": "INFO", "message": "Initializing FacePredictor au", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:31:13,948", "levelname": "INFO", "message": "Initializing FacePredictor va", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:31:14,012", "levelname": "INFO", "message": "Initializing FacePredictor align", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:31:14,314", "levelname": "INFO", "message": "Initializing BaseUtilizer objects", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:31:14,315", "levelname": "INFO", "message": "Initializing BaseUtilizer align", "taskName": "Task-3"}
# c:\Users\danie\anaconda3\envs\FaceTorch\Lib\site-packages\facetorch\analyzer\utilizer\align.py:40: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.meta = torch.load(self.downloader_meta.path_local)
# {"asctime": "2024-10-23 01:31:14,357", "levelname": "INFO", "message": "Initializing BaseUtilizer draw_boxes", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:31:14,359", "levelname": "INFO", "message": "Initializing BaseUtilizer draw_landmarks", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:31:14,361", "levelname": "INFO", "message": "Running FaceAnalyzer", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:31:14,362", "levelname": "INFO", "message": "Reading image", "taskName": "Task-3", "input": "./Curated_Dataset/Abdullah_Gul/Abdullah_Gul_0003.jpg"}
# {"asctime": "2024-10-23 01:31:14,367", "levelname": "INFO", "message": "Detecting faces", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:31:14,561", "levelname": "INFO", "message": "Number of faces: 2", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:31:14,562", "levelname": "INFO", "message": "Unifying faces", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:31:14,564", "levelname": "INFO", "message": "Predicting facial features", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:31:14,564", "levelname": "INFO", "message": "Running FacePredictor: embed", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:31:14,728", "levelname": "INFO", "message": "Running FacePredictor: verify", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:31:32,561", "levelname": "INFO", "message": "Running FacePredictor: au", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:31:33,224", "levelname": "INFO", "message": "Running FacePredictor: va", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:31:33,253", "levelname": "INFO", "message": "Running FacePredictor: align", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:31:33,593", "levelname": "INFO", "message": "Utilizing facial features", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:31:33,594", "levelname": "INFO", "message": "Running BaseUtilizer: align", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:31:33,602", "levelname": "INFO", "message": "Running BaseUtilizer: draw_boxes", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:31:33,604", "levelname": "INFO", "message": "Running BaseUtilizer: draw_landmarks", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:31:33,701", "levelname": "INFO", "message": "Initializing FaceAnalyzer", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:31:33,701", "levelname": "INFO", "message": "Initializing BaseReader", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:31:33,713", "levelname": "INFO", "message": "Initializing FaceDetector", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:31:34,139", "levelname": "INFO", "message": "Initializing FaceUnifier", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:31:34,154", "levelname": "INFO", "message": "Initializing FacePredictor objects", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:31:34,154", "levelname": "INFO", "message": "Initializing FacePredictor embed", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:31:34,517", "levelname": "INFO", "message": "Initializing FacePredictor verify", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:31:39,163", "levelname": "INFO", "message": "Initializing FacePredictor au", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:31:40,186", "levelname": "INFO", "message": "Initializing FacePredictor va", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:31:40,261", "levelname": "INFO", "message": "Initializing FacePredictor align", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:31:40,560", "levelname": "INFO", "message": "Initializing BaseUtilizer objects", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:31:40,561", "levelname": "INFO", "message": "Initializing BaseUtilizer align", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:31:40,599", "levelname": "INFO", "message": "Initializing BaseUtilizer draw_boxes", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:31:40,602", "levelname": "INFO", "message": "Initializing BaseUtilizer draw_landmarks", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:31:40,604", "levelname": "INFO", "message": "Running FaceAnalyzer", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:31:40,605", "levelname": "INFO", "message": "Reading image", "taskName": "Task-3", "input": "./Curated_Dataset/Abdullah_Gul/Abdullah_Gul_0003_hor_flipped.jpg"}
# {"asctime": "2024-10-23 01:31:40,616", "levelname": "INFO", "message": "Detecting faces", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:31:40,804", "levelname": "INFO", "message": "Number of faces: 2", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:31:40,805", "levelname": "INFO", "message": "Unifying faces", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:31:40,807", "levelname": "INFO", "message": "Predicting facial features", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:31:40,807", "levelname": "INFO", "message": "Running FacePredictor: embed", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:31:40,922", "levelname": "INFO", "message": "Running FacePredictor: verify", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:31:57,614", "levelname": "INFO", "message": "Running FacePredictor: au", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:31:58,194", "levelname": "INFO", "message": "Running FacePredictor: va", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:31:58,210", "levelname": "INFO", "message": "Running FacePredictor: align", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:31:58,369", "levelname": "INFO", "message": "Utilizing facial features", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:31:58,369", "levelname": "INFO", "message": "Running BaseUtilizer: align", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:31:58,384", "levelname": "INFO", "message": "Running BaseUtilizer: draw_boxes", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:31:58,386", "levelname": "INFO", "message": "Running BaseUtilizer: draw_landmarks", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:31:58,480", "levelname": "INFO", "message": "Initializing FaceAnalyzer", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:31:58,481", "levelname": "INFO", "message": "Initializing BaseReader", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:31:58,492", "levelname": "INFO", "message": "Initializing FaceDetector", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:31:58,856", "levelname": "INFO", "message": "Initializing FaceUnifier", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:31:58,868", "levelname": "INFO", "message": "Initializing FacePredictor objects", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:31:58,869", "levelname": "INFO", "message": "Initializing FacePredictor embed", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:31:59,161", "levelname": "INFO", "message": "Initializing FacePredictor verify", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:32:03,062", "levelname": "INFO", "message": "Initializing FacePredictor au", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:32:03,904", "levelname": "INFO", "message": "Initializing FacePredictor va", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:32:03,965", "levelname": "INFO", "message": "Initializing FacePredictor align", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:32:04,253", "levelname": "INFO", "message": "Initializing BaseUtilizer objects", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:32:04,254", "levelname": "INFO", "message": "Initializing BaseUtilizer align", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:32:04,284", "levelname": "INFO", "message": "Initializing BaseUtilizer draw_boxes", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:32:04,286", "levelname": "INFO", "message": "Initializing BaseUtilizer draw_landmarks", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:32:04,288", "levelname": "INFO", "message": "Running FaceAnalyzer", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:32:04,289", "levelname": "INFO", "message": "Reading image", "taskName": "Task-3", "input": "./Curated_Dataset/Abdullah_Gul/Abdullah_Gul_0004.jpg"}
# {"asctime": "2024-10-23 01:32:04,293", "levelname": "INFO", "message": "Detecting faces", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:32:04,492", "levelname": "INFO", "message": "Number of faces: 1", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:32:04,493", "levelname": "INFO", "message": "Unifying faces", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:32:04,494", "levelname": "INFO", "message": "Predicting facial features", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:32:04,495", "levelname": "INFO", "message": "Running FacePredictor: embed", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:32:04,621", "levelname": "INFO", "message": "Running FacePredictor: verify", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:32:22,483", "levelname": "INFO", "message": "Running FacePredictor: au", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:32:23,099", "levelname": "INFO", "message": "Running FacePredictor: va", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:32:23,114", "levelname": "INFO", "message": "Running FacePredictor: align", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:32:23,270", "levelname": "INFO", "message": "Utilizing facial features", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:32:23,270", "levelname": "INFO", "message": "Running BaseUtilizer: align", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:32:23,277", "levelname": "INFO", "message": "Running BaseUtilizer: draw_boxes", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:32:23,280", "levelname": "INFO", "message": "Running BaseUtilizer: draw_landmarks", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:32:23,441", "levelname": "INFO", "message": "Initializing FaceAnalyzer", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:32:23,441", "levelname": "INFO", "message": "Initializing BaseReader", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:32:23,452", "levelname": "INFO", "message": "Initializing FaceDetector", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:32:23,857", "levelname": "INFO", "message": "Initializing FaceUnifier", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:32:23,871", "levelname": "INFO", "message": "Initializing FacePredictor objects", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:32:23,872", "levelname": "INFO", "message": "Initializing FacePredictor embed", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:32:24,148", "levelname": "INFO", "message": "Initializing FacePredictor verify", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:32:28,690", "levelname": "INFO", "message": "Initializing FacePredictor au", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:32:29,620", "levelname": "INFO", "message": "Initializing FacePredictor va", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:32:29,687", "levelname": "INFO", "message": "Initializing FacePredictor align", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:32:30,130", "levelname": "INFO", "message": "Initializing BaseUtilizer objects", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:32:30,130", "levelname": "INFO", "message": "Initializing BaseUtilizer align", "taskName": "Task-3"}
# c:\Users\danie\anaconda3\envs\FaceTorch\Lib\site-packages\facetorch\analyzer\utilizer\align.py:40: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.meta = torch.load(self.downloader_meta.path_local)
# {"asctime": "2024-10-23 01:32:30,173", "levelname": "INFO", "message": "Initializing BaseUtilizer draw_boxes", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:32:30,176", "levelname": "INFO", "message": "Initializing BaseUtilizer draw_landmarks", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:32:30,179", "levelname": "INFO", "message": "Running FaceAnalyzer", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:32:30,179", "levelname": "INFO", "message": "Reading image", "taskName": "Task-3", "input": "./Curated_Dataset/Abdullah_Gul/Abdullah_Gul_0004_hor_flipped.jpg"}
# {"asctime": "2024-10-23 01:32:30,194", "levelname": "INFO", "message": "Detecting faces", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:32:30,468", "levelname": "INFO", "message": "Number of faces: 1", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:32:30,469", "levelname": "INFO", "message": "Unifying faces", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:32:30,470", "levelname": "INFO", "message": "Predicting facial features", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:32:30,471", "levelname": "INFO", "message": "Running FacePredictor: embed", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:32:30,600", "levelname": "INFO", "message": "Running FacePredictor: verify", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:32:48,168", "levelname": "INFO", "message": "Running FacePredictor: au", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:32:48,789", "levelname": "INFO", "message": "Running FacePredictor: va", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:32:48,806", "levelname": "INFO", "message": "Running FacePredictor: align", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:32:48,969", "levelname": "INFO", "message": "Utilizing facial features", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:32:48,969", "levelname": "INFO", "message": "Running BaseUtilizer: align", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:32:48,973", "levelname": "INFO", "message": "Running BaseUtilizer: draw_boxes", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:32:48,975", "levelname": "INFO", "message": "Running BaseUtilizer: draw_landmarks", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:32:49,092", "levelname": "INFO", "message": "Initializing FaceAnalyzer", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:32:49,092", "levelname": "INFO", "message": "Initializing BaseReader", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:32:49,104", "levelname": "INFO", "message": "Initializing FaceDetector", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:32:49,505", "levelname": "INFO", "message": "Initializing FaceUnifier", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:32:49,519", "levelname": "INFO", "message": "Initializing FacePredictor objects", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:32:49,520", "levelname": "INFO", "message": "Initializing FacePredictor embed", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:32:49,868", "levelname": "INFO", "message": "Initializing FacePredictor verify", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:32:55,051", "levelname": "INFO", "message": "Initializing FacePredictor au", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:32:56,095", "levelname": "INFO", "message": "Initializing FacePredictor va", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:32:56,161", "levelname": "INFO", "message": "Initializing FacePredictor align", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:32:56,482", "levelname": "INFO", "message": "Initializing BaseUtilizer objects", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:32:56,483", "levelname": "INFO", "message": "Initializing BaseUtilizer align", "taskName": "Task-3"}
# c:\Users\danie\anaconda3\envs\FaceTorch\Lib\site-packages\facetorch\analyzer\utilizer\align.py:40: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.meta = torch.load(self.downloader_meta.path_local)
# {"asctime": "2024-10-23 01:32:56,521", "levelname": "INFO", "message": "Initializing BaseUtilizer draw_boxes", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:32:56,523", "levelname": "INFO", "message": "Initializing BaseUtilizer draw_landmarks", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:32:56,525", "levelname": "INFO", "message": "Running FaceAnalyzer", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:32:56,526", "levelname": "INFO", "message": "Reading image", "taskName": "Task-3", "input": "./Curated_Dataset/Abdullah_Gul/Abdullah_Gul_0005.jpg"}
# {"asctime": "2024-10-23 01:32:56,531", "levelname": "INFO", "message": "Detecting faces", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:32:56,725", "levelname": "INFO", "message": "Number of faces: 1", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:32:56,726", "levelname": "INFO", "message": "Unifying faces", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:32:56,727", "levelname": "INFO", "message": "Predicting facial features", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:32:56,728", "levelname": "INFO", "message": "Running FacePredictor: embed", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:32:56,851", "levelname": "INFO", "message": "Running FacePredictor: verify", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:33:14,384", "levelname": "INFO", "message": "Running FacePredictor: au", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:33:15,131", "levelname": "INFO", "message": "Running FacePredictor: va", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:33:15,150", "levelname": "INFO", "message": "Running FacePredictor: align", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:33:15,336", "levelname": "INFO", "message": "Utilizing facial features", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:33:15,337", "levelname": "INFO", "message": "Running BaseUtilizer: align", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:33:15,344", "levelname": "INFO", "message": "Running BaseUtilizer: draw_boxes", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:33:15,347", "levelname": "INFO", "message": "Running BaseUtilizer: draw_landmarks", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:33:15,481", "levelname": "INFO", "message": "Initializing FaceAnalyzer", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:33:15,482", "levelname": "INFO", "message": "Initializing BaseReader", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:33:15,494", "levelname": "INFO", "message": "Initializing FaceDetector", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:33:15,864", "levelname": "INFO", "message": "Initializing FaceUnifier", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:33:15,877", "levelname": "INFO", "message": "Initializing FacePredictor objects", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:33:15,878", "levelname": "INFO", "message": "Initializing FacePredictor embed", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:33:16,170", "levelname": "INFO", "message": "Initializing FacePredictor verify", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:33:20,386", "levelname": "INFO", "message": "Initializing FacePredictor au", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:33:21,340", "levelname": "INFO", "message": "Initializing FacePredictor va", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:33:21,413", "levelname": "INFO", "message": "Initializing FacePredictor align", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:33:21,713", "levelname": "INFO", "message": "Initializing BaseUtilizer objects", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:33:21,713", "levelname": "INFO", "message": "Initializing BaseUtilizer align", "taskName": "Task-3"}
# c:\Users\danie\anaconda3\envs\FaceTorch\Lib\site-packages\facetorch\analyzer\utilizer\align.py:40: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.meta = torch.load(self.downloader_meta.path_local)
# {"asctime": "2024-10-23 01:33:21,752", "levelname": "INFO", "message": "Initializing BaseUtilizer draw_boxes", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:33:21,754", "levelname": "INFO", "message": "Initializing BaseUtilizer draw_landmarks", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:33:21,757", "levelname": "INFO", "message": "Running FaceAnalyzer", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:33:21,757", "levelname": "INFO", "message": "Reading image", "taskName": "Task-3", "input": "./Curated_Dataset/Abdullah_Gul/Abdullah_Gul_0005_hor_flipped.jpg"}
# {"asctime": "2024-10-23 01:33:21,767", "levelname": "INFO", "message": "Detecting faces", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:33:22,012", "levelname": "INFO", "message": "Number of faces: 1", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:33:22,013", "levelname": "INFO", "message": "Unifying faces", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:33:22,014", "levelname": "INFO", "message": "Predicting facial features", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:33:22,014", "levelname": "INFO", "message": "Running FacePredictor: embed", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:33:22,142", "levelname": "INFO", "message": "Running FacePredictor: verify", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:33:39,622", "levelname": "INFO", "message": "Running FacePredictor: au", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:33:40,249", "levelname": "INFO", "message": "Running FacePredictor: va", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:33:40,267", "levelname": "INFO", "message": "Running FacePredictor: align", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:33:40,434", "levelname": "INFO", "message": "Utilizing facial features", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:33:40,435", "levelname": "INFO", "message": "Running BaseUtilizer: align", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:33:40,438", "levelname": "INFO", "message": "Running BaseUtilizer: draw_boxes", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:33:40,440", "levelname": "INFO", "message": "Running BaseUtilizer: draw_landmarks", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:33:40,562", "levelname": "INFO", "message": "Initializing FaceAnalyzer", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:33:40,562", "levelname": "INFO", "message": "Initializing BaseReader", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:33:40,575", "levelname": "INFO", "message": "Initializing FaceDetector", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:33:40,920", "levelname": "INFO", "message": "Initializing FaceUnifier", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:33:40,934", "levelname": "INFO", "message": "Initializing FacePredictor objects", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:33:40,934", "levelname": "INFO", "message": "Initializing FacePredictor embed", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:33:41,206", "levelname": "INFO", "message": "Initializing FacePredictor verify", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:33:45,897", "levelname": "INFO", "message": "Initializing FacePredictor au", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:33:46,960", "levelname": "INFO", "message": "Initializing FacePredictor va", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:33:47,023", "levelname": "INFO", "message": "Initializing FacePredictor align", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:33:47,295", "levelname": "INFO", "message": "Initializing BaseUtilizer objects", "taskName": "Task-3"}
# {"asctime": "2024-10-23 01:33:47,296", "levelname": "INFO", "message": "Initializing BaseUtilizer align", "taskName": "Task-3"}
# c:\Users\danie\anaconda3\envs\FaceTorch\Lib\site-packages\facetorch\analyzer\utilizer\align.py:40: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.meta = torch.load(self.downloader_meta.path_local)
# ...
#   self.meta = torch.load(self.downloader_meta.path_local)
# {"asctime": "2024-10-23 03:13:35,017", "levelname": "INFO", "message": "Initializing BaseUtilizer draw_boxes", "taskName": "Task-3"}
# {"asctime": "2024-10-23 03:13:35,018", "levelname": "INFO", "message": "Initializing BaseUtilizer draw_landmarks", "taskName": "Task-3"}
# {"asctime": "2024-10-23 03:13:35,021", "levelname": "INFO", "message": "Running FaceAnalyzer", "taskName": "Task-3"}
# {"asctime": "2024-10-23 03:13:35,022", "levelname": "INFO", "message": "Reading image", "taskName": "Task-3", "input": "./Curated_Dataset/Andre_Agassi/Andre_Agassi_0015_hor_flipped.jpg"}
# {"asctime": "2024-10-23 03:13:35,032", "levelname": "INFO", "message": "Detecting faces", "taskName": "Task-3"}
# {"asctime": "2024-10-23 03:13:35,249", "levelname": "INFO", "message": "Number of faces: 1", "taskName": "Task-3"}
# {"asctime": "2024-10-23 03:13:35,250", "levelname": "INFO", "message": "Unifying faces", "taskName": "Task-3"}
# {"asctime": "2024-10-23 03:13:35,251", "levelname": "INFO", "message": "Predicting facial features", "taskName": "Task-3"}
# {"asctime": "2024-10-23 03:13:35,251", "levelname": "INFO", "message": "Running FacePredictor: embed", "taskName": "Task-3"}
# {"asctime": "2024-10-23 03:13:35,378", "levelname": "INFO", "message": "Running FacePredictor: verify", "taskName": "Task-3"}
# {"asctime": "2024-10-23 03:13:51,623", "levelname": "INFO", "message": "Running FacePredictor: au", "taskName": "Task-3"}
# {"asctime": "2024-10-23 03:13:52,252", "levelname": "INFO", "message": "Running FacePredictor: va", "taskName": "Task-3"}
# {"asctime": "2024-10-23 03:13:52,268", "levelname": "INFO", "message": "Running FacePredictor: align", "taskName": "Task-3"}
# {"asctime": "2024-10-23 03:13:52,434", "levelname": "INFO", "message": "Utilizing facial features", "taskName": "Task-3"}
# {"asctime": "2024-10-23 03:13:52,435", "levelname": "INFO", "message": "Running BaseUtilizer: align", "taskName": "Task-3"}
# {"asctime": "2024-10-23 03:13:52,444", "levelname": "INFO", "message": "Running BaseUtilizer: draw_boxes", "taskName": "Task-3"}
# {"asctime": "2024-10-23 03:13:52,446", "levelname": "INFO", "message": "Running BaseUtilizer: draw_landmarks", "taskName": "Task-3"}
# {"asctime": "2024-10-23 03:13:52,616", "levelname": "INFO", "message": "Initializing FaceAnalyzer", "taskName": "Task-3"}
# {"asctime": "2024-10-23 03:13:52,616", "levelname": "INFO", "message": "Initializing BaseReader", "taskName": "Task-3"}
# {"asctime": "2024-10-23 03:13:52,630", "levelname": "INFO", "message": "Initializing FaceDetector", "taskName": "Task-3"}
# {"asctime": "2024-10-23 03:13:53,046", "levelname": "INFO", "message": "Initializing FaceUnifier", "taskName": "Task-3"}
# {"asctime": "2024-10-23 03:13:53,060", "levelname": "INFO", "message": "Initializing FacePredictor objects", "taskName": "Task-3"}
# {"asctime": "2024-10-23 03:13:53,061", "levelname": "INFO", "message": "Initializing FacePredictor embed", "taskName": "Task-3"}
# {"asctime": "2024-10-23 03:13:53,398", "levelname": "INFO", "message": "Initializing FacePredictor verify", "taskName": "Task-3"}
# {"asctime": "2024-10-23 03:13:58,115", "levelname": "INFO", "message": "Initializing FacePredictor au", "taskName": "Task-3"}
# {"asctime": "2024-10-23 03:13:59,142", "levelname": "INFO", "message": "Initializing FacePredictor va", "taskName": "Task-3"}
# {"asctime": "2024-10-23 03:13:59,209", "levelname": "INFO", "message": "Initializing FacePredictor align", "taskName": "Task-3"}
# {"asctime": "2024-10-23 03:13:59,465", "levelname": "INFO", "message": "Initializing BaseUtilizer objects", "taskName": "Task-3"}
# {"asctime": "2024-10-23 03:13:59,466", "levelname": "INFO", "message": "Initializing BaseUtilizer align", "taskName": "Task-3"}
# c:\Users\danie\anaconda3\envs\FaceTorch\Lib\site-packages\facetorch\analyzer\utilizer\align.py:40: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.meta = torch.load(self.downloader_meta.path_local)
# {"asctime": "2024-10-23 03:13:59,500", "levelname": "INFO", "message": "Initializing BaseUtilizer draw_boxes", "taskName": "Task-3"}
# {"asctime": "2024-10-23 03:13:59,502", "levelname": "INFO", "message": "Initializing BaseUtilizer draw_landmarks", "taskName": "Task-3"}
# {"asctime": "2024-10-23 03:13:59,504", "levelname": "INFO", "message": "Running FaceAnalyzer", "taskName": "Task-3"}
# {"asctime": "2024-10-23 03:13:59,505", "levelname": "INFO", "message": "Reading image", "taskName": "Task-3", "input": "./Curated_Dataset/Andre_Agassi/Andre_Agassi_0016.jpg"}
# {"asctime": "2024-10-23 03:13:59,509", "levelname": "INFO", "message": "Detecting faces", "taskName": "Task-3"}
# {"asctime": "2024-10-23 03:13:59,699", "levelname": "INFO", "message": "Number of faces: 1", "taskName": "Task-3"}
# {"asctime": "2024-10-23 03:13:59,700", "levelname": "INFO", "message": "Unifying faces", "taskName": "Task-3"}
# {"asctime": "2024-10-23 03:13:59,701", "levelname": "INFO", "message": "Predicting facial features", "taskName": "Task-3"}
# {"asctime": "2024-10-23 03:13:59,702", "levelname": "INFO", "message": "Running FacePredictor: embed", "taskName": "Task-3"}
# {"asctime": "2024-10-23 03:13:59,815", "levelname": "INFO", "message": "Running FacePredictor: verify", "taskName": "Task-3"}
# {"asctime": "2024-10-23 03:14:13,830", "levelname": "INFO", "message": "Running FacePredictor: au", "taskName": "Task-3"}
# {"asctime": "2024-10-23 03:14:14,356", "levelname": "INFO", "message": "Running FacePredictor: va", "taskName": "Task-3"}
# {"asctime": "2024-10-23 03:14:14,371", "levelname": "INFO", "message": "Running FacePredictor: align", "taskName": "Task-3"}
# {"asctime": "2024-10-23 03:14:14,519", "levelname": "INFO", "message": "Utilizing facial features", "taskName": "Task-3"}
# {"asctime": "2024-10-23 03:14:14,520", "levelname": "INFO", "message": "Running BaseUtilizer: align", "taskName": "Task-3"}
# {"asctime": "2024-10-23 03:14:14,524", "levelname": "INFO", "message": "Running BaseUtilizer: draw_boxes", "taskName": "Task-3"}
# {"asctime": "2024-10-23 03:14:14,525", "levelname": "INFO", "message": "Running BaseUtilizer: draw_landmarks", "taskName": "Task-3"}
# {"asctime": "2024-10-23 03:14:14,686", "levelname": "INFO", "message": "Initializing FaceAnalyzer", "taskName": "Task-3"}
# {"asctime": "2024-10-23 03:14:14,687", "levelname": "INFO", "message": "Initializing BaseReader", "taskName": "Task-3"}
# {"asctime": "2024-10-23 03:14:14,698", "levelname": "INFO", "message": "Initializing FaceDetector", "taskName": "Task-3"}
# {"asctime": "2024-10-23 03:14:15,063", "levelname": "INFO", "message": "Initializing FaceUnifier", "taskName": "Task-3"}
# {"asctime": "2024-10-23 03:14:15,078", "levelname": "INFO", "message": "Initializing FacePredictor objects", "taskName": "Task-3"}
# {"asctime": "2024-10-23 03:14:15,078", "levelname": "INFO", "message": "Initializing FacePredictor embed", "taskName": "Task-3"}
# {"asctime": "2024-10-23 03:14:15,382", "levelname": "INFO", "message": "Initializing FacePredictor verify", "taskName": "Task-3"}
# {"asctime": "2024-10-23 03:14:18,991", "levelname": "INFO", "message": "Initializing FacePredictor au", "taskName": "Task-3"}
# {"asctime": "2024-10-23 03:14:19,974", "levelname": "INFO", "message": "Initializing FacePredictor va", "taskName": "Task-3"}
# {"asctime": "2024-10-23 03:14:20,040", "levelname": "INFO", "message": "Initializing FacePredictor align", "taskName": "Task-3"}
# {"asctime": "2024-10-23 03:14:20,342", "levelname": "INFO", "message": "Initializing BaseUtilizer objects", "taskName": "Task-3"}
# {"asctime": "2024-10-23 03:14:20,342", "levelname": "INFO", "message": "Initializing BaseUtilizer align", "taskName": "Task-3"}
# c:\Users\danie\anaconda3\envs\FaceTorch\Lib\site-packages\facetorch\analyzer\utilizer\align.py:40: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.meta = torch.load(self.downloader_meta.path_local)
# {"asctime": "2024-10-23 03:14:20,386", "levelname": "INFO", "message": "Initializing BaseUtilizer draw_boxes", "taskName": "Task-3"}
# {"asctime": "2024-10-23 03:14:20,388", "levelname": "INFO", "message": "Initializing BaseUtilizer draw_landmarks", "taskName": "Task-3"}
# {"asctime": "2024-10-23 03:14:20,390", "levelname": "INFO", "message": "Running FaceAnalyzer", "taskName": "Task-3"}
# {"asctime": "2024-10-23 03:14:20,391", "levelname": "INFO", "message": "Reading image", "taskName": "Task-3", "input": "./Curated_Dataset/Andre_Agassi/Andre_Agassi_0016_hor_flipped.jpg"}
# {"asctime": "2024-10-23 03:14:20,403", "levelname": "INFO", "message": "Detecting faces", "taskName": "Task-3"}
# {"asctime": "2024-10-23 03:14:20,596", "levelname": "INFO", "message": "Number of faces: 1", "taskName": "Task-3"}
# {"asctime": "2024-10-23 03:14:20,596", "levelname": "INFO", "message": "Unifying faces", "taskName": "Task-3"}
# {"asctime": "2024-10-23 03:14:20,598", "levelname": "INFO", "message": "Predicting facial features", "taskName": "Task-3"}
# {"asctime": "2024-10-23 03:14:20,598", "levelname": "INFO", "message": "Running FacePredictor: embed", "taskName": "Task-3"}
# {"asctime": "2024-10-23 03:14:20,729", "levelname": "INFO", "message": "Running FacePredictor: verify", "taskName": "Task-3"}
# {"asctime": "2024-10-23 03:14:36,401", "levelname": "INFO", "message": "Running FacePredictor: au", "taskName": "Task-3"}
# {"asctime": "2024-10-23 03:14:37,017", "levelname": "INFO", "message": "Running FacePredictor: va", "taskName": "Task-3"}
# {"asctime": "2024-10-23 03:14:37,032", "levelname": "INFO", "message": "Running FacePredictor: align", "taskName": "Task-3"}
# {"asctime": "2024-10-23 03:14:37,189", "levelname": "INFO", "message": "Utilizing facial features", "taskName": "Task-3"}
# {"asctime": "2024-10-23 03:14:37,190", "levelname": "INFO", "message": "Running BaseUtilizer: align", "taskName": "Task-3"}
# {"asctime": "2024-10-23 03:14:37,195", "levelname": "INFO", "message": "Running BaseUtilizer: draw_boxes", "taskName": "Task-3"}
# {"asctime": "2024-10-23 03:14:37,197", "levelname": "INFO", "message": "Running BaseUtilizer: draw_landmarks", "taskName": "Task-3"}
# {"asctime": "2024-10-23 03:14:37,335", "levelname": "INFO", "message": "Initializing FaceAnalyzer", "taskName": "Task-3"}
# {"asctime": "2024-10-23 03:14:37,336", "levelname": "INFO", "message": "Initializing BaseReader", "taskName": "Task-3"}
# {"asctime": "2024-10-23 03:14:37,349", "levelname": "INFO", "message": "Initializing FaceDetector", "taskName": "Task-3"}
# {"asctime": "2024-10-23 03:14:37,713", "levelname": "INFO", "message": "Initializing FaceUnifier", "taskName": "Task-3"}
# {"asctime": "2024-10-23 03:14:37,727", "levelname": "INFO", "message": "Initializing FacePredictor objects", "taskName": "Task-3"}
# {"asctime": "2024-10-23 03:14:37,728", "levelname": "INFO", "message": "Initializing FacePredictor embed", "taskName": "Task-3"}
# {"asctime": "2024-10-23 03:14:38,042", "levelname": "INFO", "message": "Initializing FacePredictor verify", "taskName": "Task-3"}
# {"asctime": "2024-10-23 03:14:41,491", "levelname": "INFO", "message": "Initializing FacePredictor au", "taskName": "Task-3"}
# {"asctime": "2024-10-23 03:14:42,355", "levelname": "INFO", "message": "Initializing FacePredictor va", "taskName": "Task-3"}
# {"asctime": "2024-10-23 03:14:42,420", "levelname": "INFO", "message": "Initializing FacePredictor align", "taskName": "Task-3"}
# {"asctime": "2024-10-23 03:14:42,707", "levelname": "INFO", "message": "Initializing BaseUtilizer objects", "taskName": "Task-3"}
# {"asctime": "2024-10-23 03:14:42,707", "levelname": "INFO", "message": "Initializing BaseUtilizer align", "taskName": "Task-3"}
# c:\Users\danie\anaconda3\envs\FaceTorch\Lib\site-packages\facetorch\analyzer\utilizer\align.py:40: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.meta = torch.load(self.downloader_meta.path_local)
# {"asctime": "2024-10-23 03:14:42,740", "levelname": "INFO", "message": "Initializing BaseUtilizer draw_boxes", "taskName": "Task-3"}
# {"asctime": "2024-10-23 03:14:42,743", "levelname": "INFO", "message": "Initializing BaseUtilizer draw_landmarks", "taskName": "Task-3"}
# {"asctime": "2024-10-23 03:14:42,745", "levelname": "INFO", "message": "Running FaceAnalyzer", "taskName": "Task-3"}
# {"asctime": "2024-10-23 03:14:42,746", "levelname": "INFO", "message": "Reading image", "taskName": "Task-3", "input": "./Curated_Dataset/Andre_Agassi/Andre_Agassi_0017.jpg"}
# {"asctime": "2024-10-23 03:14:42,749", "levelname": "INFO", "message": "Detecting faces", "taskName": "Task-3"}
# {"asctime": "2024-10-23 03:14:42,926", "levelname": "INFO", "message": "Number of faces: 1", "taskName": "Task-3"}
# {"asctime": "2024-10-23 03:14:42,927", "levelname": "INFO", "message": "Unifying faces", "taskName": "Task-3"}
# {"asctime": "2024-10-23 03:14:42,928", "levelname": "INFO", "message": "Predicting facial features", "taskName": "Task-3"}
# {"asctime": "2024-10-23 03:14:42,928", "levelname": "INFO", "message": "Running FacePredictor: embed", "taskName": "Task-3"}
# {"asctime": "2024-10-23 03:14:43,057", "levelname": "INFO", "message": "Running FacePredictor: verify", "taskName": "Task-3"}
