# %%
from facetorch import FaceAnalyzer
from facetorch.analyzer.utilizer import LandmarkDrawerTorch
from omegaconf import OmegaConf
from torch.nn.functional import cosine_similarity
from typing import Dict
import operator
import torchvision
import os
import shutil
import torch
import numpy as np
import pandas as pd

# %%
DATASET_PATH = './Curated_Dataset/'
ANCHOR_PATH = './dataset/anchor_points_dataset/'
FACE_PATH = './dataset/face_dataset/'

if os.path.exists(FACE_PATH):
    shutil.rmtree(FACE_PATH)

if os.path.exists(ANCHOR_PATH):
    shutil.rmtree(ANCHOR_PATH)

os.makedirs(FACE_PATH)
os.makedirs(ANCHOR_PATH)

cfg = OmegaConf.load("./gpu.config.yml")

# %%
from scipy.spatial.transform import Rotation as R

def Rotate_Face(pts):
    data = pts[0]

    x = data[0, :]
    y = data[1, :]
    z = data[2, :]

    face_tensor = torch.stack([x, y, z], dim=1).to('cuda:0')
    # Väldigt hustler-lösning, får inte skiten att se bra ut

    sum_vectors = torch.sum(face_tensor, dim=0)
    centroid = sum_vectors / face_tensor.shape[0]
    face_tensor_orgin = (face_tensor - centroid).cpu().numpy()


    P1 = face_tensor_orgin[0]
    P2 = face_tensor_orgin[16]

    y1 = P1[1]
    y2 = P2[1]

    while abs(y1 - y2) > 1:
        r = R.from_euler('z', -0.1, degrees=True)
        face_tensor_orgin =  face_tensor_orgin @ r.as_matrix().T
        P1 = face_tensor_orgin[0]
        P2 = face_tensor_orgin[16]
        y1 = P1[1]
        y2 = P2[1]



    ### VET INTE OM DETTA FUNKAR ###
    z1 = P1[2]
    z2 = P2[2]
    x = face_tensor_orgin[33][0]

    i = 0.1
    if x > 0:
        i = -0.1

    while abs(z1 - z2) > 1:
        r = R.from_euler('y', i, degrees=True)
        face_tensor_orgin =  face_tensor_orgin @ r.as_matrix().T
        P1 = face_tensor_orgin[0]
        P2 = face_tensor_orgin[16]
        z1 = P1[2]
        z2 = P2[2]

    ### VET INTE OM DETTA FUNKAR SLUT ###

    if face_tensor_orgin[25][1] > 0:
        r = R.from_euler('z', 180, degrees=True)
        face_tensor_orgin =  face_tensor_orgin @ r.as_matrix().T
    
    return face_tensor_orgin

def fft_func(arr):
    norm = np.linalg.norm(arr)  # Calculate the L2 norm of the data
    normalized_data = arr / norm
    transformed = np.fft.fftn(normalized_data)

    magnintude = np.abs(transformed)

    transformed_array = np.zeros(shape=(magnintude.shape[0]-1, magnintude.shape[1]))
    for i in range(0,3):
        background_value = magnintude[:,i][0]
        column = magnintude[:,i][1:]

        column = column / background_value

        transformed_array[:,i] = column


    return transformed_array

def Process_Image(path_img):
    """
    Processes the input image and extracts important features (anchor points).

    Args:
        path_to_image (str): The file path to the image to be processed.

    Returns:
        processed_image: The image after processing 
        anchor_points: A set of key points or features detected in the image (e.g., corners, edges, or other important features).
    """
    analyzer = FaceAnalyzer(cfg.analyzer)
    response = analyzer.run(
        path_image=path_img,
        batch_size=cfg.batch_size,
        return_img_data=cfg.return_img_data,
        include_tensors=cfg.include_tensors,
        fix_img_size=cfg.fix_img_size
    )
    return response

def Save_Processed_Image(response, path):
    pil_image = torchvision.transforms.functional.to_pil_image(response.img)
    pil_image.save(path)
    return 

def Save_Processed_Feature_Vector(arr, name, data):
    arr = Rotate_Face(arr)
    fft = fft_func(arr)
    flat_list = fft.reshape(-1)
    data.loc[len(data)] = flat_list.tolist() + [name]

    return

# %%
columns = [f'feature_{i}' for i in range(1, 202)] + ['label']
df = pd.DataFrame(columns=columns)
for name in os.listdir(DATASET_PATH):

    temp_path = DATASET_PATH + f'{name}'  
    temp_anchor_path = ANCHOR_PATH + f'{name}'
    temp_face_path = FACE_PATH + f'{name}'

    if os.path.exists(temp_face_path):
        shutil.rmtree(temp_face_path)


    os.makedirs(temp_face_path)
    i = 0
    for image in os.listdir(temp_path):

        response = Process_Image( temp_path + f'/{image}')
        pts = [face.preds["align"].other["lmk3d"].cpu() for face in response.faces]
        if len(pts) == 1:
            
            Save_Processed_Image(response, f'{temp_face_path}/{name}{i}.jpg')
            Save_Processed_Feature_Vector(pts, name, df)
            i += 1
    
    if os.path.isdir(temp_face_path) and len(os.listdir(temp_face_path)) == 0:
        os.rmdir(temp_face_path)
    
    df.to_csv(ANCHOR_PATH + 'processed_data.csv', index=False)
# Out:
# {"asctime": "2024-10-18 13:52:41,132", "levelname": "INFO", "message": "Initializing FaceAnalyzer"}
# {"asctime": "2024-10-18 13:52:41,133", "levelname": "INFO", "message": "Initializing BaseReader"}
# {"asctime": "2024-10-18 13:52:41,570", "levelname": "INFO", "message": "Initializing FaceDetector"}
# {"asctime": "2024-10-18 13:52:41,992", "levelname": "INFO", "message": "Initializing FaceUnifier"}
# {"asctime": "2024-10-18 13:52:42,004", "levelname": "INFO", "message": "Initializing FacePredictor objects"}
# {"asctime": "2024-10-18 13:52:42,005", "levelname": "INFO", "message": "Initializing FacePredictor embed"}
# {"asctime": "2024-10-18 13:52:42,214", "levelname": "INFO", "message": "Initializing FacePredictor verify"}
# {"asctime": "2024-10-18 13:52:43,385", "levelname": "INFO", "message": "Initializing FacePredictor au"}
# {"asctime": "2024-10-18 13:52:44,035", "levelname": "INFO", "message": "Initializing FacePredictor va"}
# {"asctime": "2024-10-18 13:52:44,086", "levelname": "INFO", "message": "Initializing FacePredictor align"}
# {"asctime": "2024-10-18 13:52:44,282", "levelname": "INFO", "message": "Initializing BaseUtilizer objects"}
# {"asctime": "2024-10-18 13:52:44,283", "levelname": "INFO", "message": "Initializing BaseUtilizer align"}
# /home/boman/anaconda3/envs/myenv/lib/python3.9/site-packages/facetorch/analyzer/utilizer/align.py:40: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.meta = torch.load(self.downloader_meta.path_local)
# {"asctime": "2024-10-18 13:52:44,367", "levelname": "INFO", "message": "Initializing BaseUtilizer draw_boxes"}
# {"asctime": "2024-10-18 13:52:44,369", "levelname": "INFO", "message": "Initializing BaseUtilizer draw_landmarks"}
# {"asctime": "2024-10-18 13:52:44,372", "levelname": "INFO", "message": "Running FaceAnalyzer"}
# {"asctime": "2024-10-18 13:52:44,373", "levelname": "INFO", "message": "Reading image", "input": "./Curated_Dataset/Mike_Weir/Mike_Weir_0011.jpg"}
# {"asctime": "2024-10-18 13:52:44,476", "levelname": "INFO", "message": "Detecting faces"}
# {"asctime": "2024-10-18 13:52:45,780", "levelname": "INFO", "message": "Number of faces: 1"}
# {"asctime": "2024-10-18 13:52:45,780", "levelname": "INFO", "message": "Unifying faces"}
# {"asctime": "2024-10-18 13:52:45,798", "levelname": "INFO", "message": "Predicting facial features"}
# {"asctime": "2024-10-18 13:52:45,799", "levelname": "INFO", "message": "Running FacePredictor: embed"}
# {"asctime": "2024-10-18 13:52:45,960", "levelname": "INFO", "message": "Running FacePredictor: verify"}
# {"asctime": "2024-10-18 13:52:48,832", "levelname": "INFO", "message": "Running FacePredictor: au"}
# {"asctime": "2024-10-18 13:52:49,371", "levelname": "INFO", "message": "Running FacePredictor: va"}
# {"asctime": "2024-10-18 13:52:49,395", "levelname": "INFO", "message": "Running FacePredictor: align"}
# {"asctime": "2024-10-18 13:52:49,661", "levelname": "INFO", "message": "Utilizing facial features"}
# {"asctime": "2024-10-18 13:52:49,661", "levelname": "INFO", "message": "Running BaseUtilizer: align"}
# /home/boman/anaconda3/envs/myenv/lib/python3.9/site-packages/facetorch/analyzer/utilizer/align.py:223: UserWarning: Using torch.cross without specifying the dim arg is deprecated.
# Please either pass the dim explicitly or simply use torch.linalg.cross.
# The default value of dim will change to agree with that of linalg.cross in a future release. (Triggered internally at ../aten/src/ATen/native/Cross.cpp:62.)
#   r3 = torch.cross(r1, r2)
# {"asctime": "2024-10-18 13:52:49,691", "levelname": "INFO", "message": "Running BaseUtilizer: draw_boxes"}
# {"asctime": "2024-10-18 13:52:49,706", "levelname": "INFO", "message": "Running BaseUtilizer: draw_landmarks"}
# {"asctime": "2024-10-18 13:52:49,845", "levelname": "INFO", "message": "Initializing FaceAnalyzer"}
# {"asctime": "2024-10-18 13:52:49,845", "levelname": "INFO", "message": "Initializing BaseReader"}
# {"asctime": "2024-10-18 13:52:49,858", "levelname": "INFO", "message": "Initializing FaceDetector"}
# {"asctime": "2024-10-18 13:52:50,105", "levelname": "INFO", "message": "Initializing FaceUnifier"}
# {"asctime": "2024-10-18 13:52:50,117", "levelname": "INFO", "message": "Initializing FacePredictor objects"}
# {"asctime": "2024-10-18 13:52:50,118", "levelname": "INFO", "message": "Initializing FacePredictor embed"}
# {"asctime": "2024-10-18 13:52:50,306", "levelname": "INFO", "message": "Initializing FacePredictor verify"}
# {"asctime": "2024-10-18 13:52:51,469", "levelname": "INFO", "message": "Initializing FacePredictor au"}
# {"asctime": "2024-10-18 13:52:52,106", "levelname": "INFO", "message": "Initializing FacePredictor va"}
# {"asctime": "2024-10-18 13:52:52,154", "levelname": "INFO", "message": "Initializing FacePredictor align"}
# {"asctime": "2024-10-18 13:52:52,343", "levelname": "INFO", "message": "Initializing BaseUtilizer objects"}
# {"asctime": "2024-10-18 13:52:52,343", "levelname": "INFO", "message": "Initializing BaseUtilizer align"}
# /home/boman/anaconda3/envs/myenv/lib/python3.9/site-packages/facetorch/analyzer/utilizer/align.py:40: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.meta = torch.load(self.downloader_meta.path_local)
# {"asctime": "2024-10-18 13:52:52,376", "levelname": "INFO", "message": "Initializing BaseUtilizer draw_boxes"}
# {"asctime": "2024-10-18 13:52:52,379", "levelname": "INFO", "message": "Initializing BaseUtilizer draw_landmarks"}
# {"asctime": "2024-10-18 13:52:52,382", "levelname": "INFO", "message": "Running FaceAnalyzer"}
# {"asctime": "2024-10-18 13:52:52,383", "levelname": "INFO", "message": "Reading image", "input": "./Curated_Dataset/Mike_Weir/Mike_Weir_0003.jpg"}
# {"asctime": "2024-10-18 13:52:52,414", "levelname": "INFO", "message": "Detecting faces"}
# {"asctime": "2024-10-18 13:52:52,592", "levelname": "INFO", "message": "Number of faces: 1"}
# {"asctime": "2024-10-18 13:52:52,593", "levelname": "INFO", "message": "Unifying faces"}
# {"asctime": "2024-10-18 13:52:52,610", "levelname": "INFO", "message": "Predicting facial features"}
# {"asctime": "2024-10-18 13:52:52,610", "levelname": "INFO", "message": "Running FacePredictor: embed"}
# {"asctime": "2024-10-18 13:52:52,705", "levelname": "INFO", "message": "Running FacePredictor: verify"}
# {"asctime": "2024-10-18 13:52:55,535", "levelname": "INFO", "message": "Running FacePredictor: au"}
# {"asctime": "2024-10-18 13:52:56,050", "levelname": "INFO", "message": "Running FacePredictor: va"}
# {"asctime": "2024-10-18 13:52:56,062", "levelname": "INFO", "message": "Running FacePredictor: align"}
# {"asctime": "2024-10-18 13:52:56,204", "levelname": "INFO", "message": "Utilizing facial features"}
# {"asctime": "2024-10-18 13:52:56,205", "levelname": "INFO", "message": "Running BaseUtilizer: align"}
# {"asctime": "2024-10-18 13:52:56,207", "levelname": "INFO", "message": "Running BaseUtilizer: draw_boxes"}
# {"asctime": "2024-10-18 13:52:56,209", "levelname": "INFO", "message": "Running BaseUtilizer: draw_landmarks"}
# {"asctime": "2024-10-18 13:52:56,354", "levelname": "INFO", "message": "Initializing FaceAnalyzer"}
# {"asctime": "2024-10-18 13:52:56,355", "levelname": "INFO", "message": "Initializing BaseReader"}
# {"asctime": "2024-10-18 13:52:56,368", "levelname": "INFO", "message": "Initializing FaceDetector"}
# {"asctime": "2024-10-18 13:52:56,606", "levelname": "INFO", "message": "Initializing FaceUnifier"}
# {"asctime": "2024-10-18 13:52:56,620", "levelname": "INFO", "message": "Initializing FacePredictor objects"}
# {"asctime": "2024-10-18 13:52:56,620", "levelname": "INFO", "message": "Initializing FacePredictor embed"}
# {"asctime": "2024-10-18 13:52:56,809", "levelname": "INFO", "message": "Initializing FacePredictor verify"}
# {"asctime": "2024-10-18 13:52:57,936", "levelname": "INFO", "message": "Initializing FacePredictor au"}
# {"asctime": "2024-10-18 13:52:58,655", "levelname": "INFO", "message": "Initializing FacePredictor va"}
# {"asctime": "2024-10-18 13:52:58,698", "levelname": "INFO", "message": "Initializing FacePredictor align"}
# {"asctime": "2024-10-18 13:52:58,890", "levelname": "INFO", "message": "Initializing BaseUtilizer objects"}
# {"asctime": "2024-10-18 13:52:58,890", "levelname": "INFO", "message": "Initializing BaseUtilizer align"}
# /home/boman/anaconda3/envs/myenv/lib/python3.9/site-packages/facetorch/analyzer/utilizer/align.py:40: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.meta = torch.load(self.downloader_meta.path_local)
# {"asctime": "2024-10-18 13:52:58,916", "levelname": "INFO", "message": "Initializing BaseUtilizer draw_boxes"}
# {"asctime": "2024-10-18 13:52:58,918", "levelname": "INFO", "message": "Initializing BaseUtilizer draw_landmarks"}
# {"asctime": "2024-10-18 13:52:58,920", "levelname": "INFO", "message": "Running FaceAnalyzer"}
# {"asctime": "2024-10-18 13:52:58,921", "levelname": "INFO", "message": "Reading image", "input": "./Curated_Dataset/Mike_Weir/Mike_Weir_0002.jpg"}
# {"asctime": "2024-10-18 13:52:58,923", "levelname": "INFO", "message": "Detecting faces"}
# {"asctime": "2024-10-18 13:52:59,082", "levelname": "INFO", "message": "Number of faces: 1"}
# {"asctime": "2024-10-18 13:52:59,082", "levelname": "INFO", "message": "Unifying faces"}
# {"asctime": "2024-10-18 13:52:59,083", "levelname": "INFO", "message": "Predicting facial features"}
# {"asctime": "2024-10-18 13:52:59,084", "levelname": "INFO", "message": "Running FacePredictor: embed"}
# {"asctime": "2024-10-18 13:52:59,181", "levelname": "INFO", "message": "Running FacePredictor: verify"}
# {"asctime": "2024-10-18 13:53:02,064", "levelname": "INFO", "message": "Running FacePredictor: au"}
# {"asctime": "2024-10-18 13:53:02,667", "levelname": "INFO", "message": "Running FacePredictor: va"}
# {"asctime": "2024-10-18 13:53:02,681", "levelname": "INFO", "message": "Running FacePredictor: align"}
# {"asctime": "2024-10-18 13:53:02,803", "levelname": "INFO", "message": "Utilizing facial features"}
# {"asctime": "2024-10-18 13:53:02,804", "levelname": "INFO", "message": "Running BaseUtilizer: align"}
# {"asctime": "2024-10-18 13:53:02,810", "levelname": "INFO", "message": "Running BaseUtilizer: draw_boxes"}
# {"asctime": "2024-10-18 13:53:02,812", "levelname": "INFO", "message": "Running BaseUtilizer: draw_landmarks"}
# {"asctime": "2024-10-18 13:53:02,945", "levelname": "INFO", "message": "Initializing FaceAnalyzer"}
# {"asctime": "2024-10-18 13:53:02,946", "levelname": "INFO", "message": "Initializing BaseReader"}
# {"asctime": "2024-10-18 13:53:02,955", "levelname": "INFO", "message": "Initializing FaceDetector"}
# {"asctime": "2024-10-18 13:53:03,199", "levelname": "INFO", "message": "Initializing FaceUnifier"}
# {"asctime": "2024-10-18 13:53:03,213", "levelname": "INFO", "message": "Initializing FacePredictor objects"}
# {"asctime": "2024-10-18 13:53:03,214", "levelname": "INFO", "message": "Initializing FacePredictor embed"}
# {"asctime": "2024-10-18 13:53:03,402", "levelname": "INFO", "message": "Initializing FacePredictor verify"}
# {"asctime": "2024-10-18 13:53:04,567", "levelname": "INFO", "message": "Initializing FacePredictor au"}
# {"asctime": "2024-10-18 13:53:05,159", "levelname": "INFO", "message": "Initializing FacePredictor va"}
# {"asctime": "2024-10-18 13:53:05,207", "levelname": "INFO", "message": "Initializing FacePredictor align"}
# {"asctime": "2024-10-18 13:53:05,392", "levelname": "INFO", "message": "Initializing BaseUtilizer objects"}
# {"asctime": "2024-10-18 13:53:05,392", "levelname": "INFO", "message": "Initializing BaseUtilizer align"}
# /home/boman/anaconda3/envs/myenv/lib/python3.9/site-packages/facetorch/analyzer/utilizer/align.py:40: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.meta = torch.load(self.downloader_meta.path_local)
# {"asctime": "2024-10-18 13:53:05,414", "levelname": "INFO", "message": "Initializing BaseUtilizer draw_boxes"}
# {"asctime": "2024-10-18 13:53:05,416", "levelname": "INFO", "message": "Initializing BaseUtilizer draw_landmarks"}
# {"asctime": "2024-10-18 13:53:05,418", "levelname": "INFO", "message": "Running FaceAnalyzer"}
# {"asctime": "2024-10-18 13:53:05,419", "levelname": "INFO", "message": "Reading image", "input": "./Curated_Dataset/Mike_Weir/Mike_Weir_0008.jpg"}
# {"asctime": "2024-10-18 13:53:05,423", "levelname": "INFO", "message": "Detecting faces"}
# {"asctime": "2024-10-18 13:53:05,580", "levelname": "INFO", "message": "Number of faces: 1"}
# {"asctime": "2024-10-18 13:53:05,581", "levelname": "INFO", "message": "Unifying faces"}
# {"asctime": "2024-10-18 13
"levelname": "INFO", "message": "Initializing FacePredictor au"}
# {"asctime": "2024-10-18 13:57:44,919", "levelname": "INFO", "message": "Initializing FacePredictor va"}
# {"asctime": "2024-10-18 13:57:44,969", "levelname": "INFO", "message": "Initializing FacePredictor align"}
# {"asctime": "2024-10-18 13:57:45,171", "levelname": "INFO", "message": "Initializing BaseUtilizer objects"}
# {"asctime": "2024-10-18 13:57:45,172", "levelname": "INFO", "message": "Initializing BaseUtilizer align"}
# /home/boman/anaconda3/envs/myenv/lib/python3.9/site-packages/facetorch/analyzer/utilizer/align.py:40: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.meta = torch.load(self.downloader_meta.path_local)
# {"asctime": "2024-10-18 13:57:45,197", "levelname": "INFO", "message": "Initializing BaseUtilizer draw_boxes"}
# {"asctime": "2024-10-18 13:57:45,199", "levelname": "INFO", "message": "Initializing BaseUtilizer draw_landmarks"}
# {"asctime": "2024-10-18 13:57:45,201", "levelname": "INFO", "message": "Running FaceAnalyzer"}
# {"asctime": "2024-10-18 13:57:45,202", "levelname": "INFO", "message": "Reading image", "input": "./Curated_Dataset/Michael_Schumacher/Michael_Schumacher_0008.jpg"}
# {"asctime": "2024-10-18 13:57:45,205", "levelname": "INFO", "message": "Detecting faces"}
# {"asctime": "2024-10-18 13:57:45,367", "levelname": "INFO", "message": "Number of faces: 1"}
# {"asctime": "2024-10-18 13:57:45,367", "levelname": "INFO", "message": "Unifying faces"}
# {"asctime": "2024-10-18 13:57:45,368", "levelname": "INFO", "message": "Predicting facial features"}
# {"asctime": "2024-10-18 13:57:45,368", "levelname": "INFO", "message": "Running FacePredictor: embed"}
# {"asctime": "2024-10-18 13:57:45,469", "levelname": "INFO", "message": "Running FacePredictor: verify"}
# {"asctime": "2024-10-18 13:57:48,264", "levelname": "INFO", "message": "Running FacePredictor: au"}
# {"asctime": "2024-10-18 13:57:48,932", "levelname": "INFO", "message": "Running FacePredictor: va"}
# {"asctime": "2024-10-18 13:57:48,952", "levelname": "INFO", "message": "Running FacePredictor: align"}
# {"asctime": "2024-10-18 13:57:49,126", "levelname": "INFO", "message": "Utilizing facial features"}
# {"asctime": "2024-10-18 13:57:49,126", "levelname": "INFO", "message": "Running BaseUtilizer: align"}
# {"asctime": "2024-10-18 13:57:49,132", "levelname": "INFO", "message": "Running BaseUtilizer: draw_boxes"}
# {"asctime": "2024-10-18 13:57:49,134", "levelname": "INFO", "message": "Running BaseUtilizer: draw_landmarks"}
# {"asctime": "2024-10-18 13:57:49,370", "levelname": "INFO", "message": "Initializing FaceAnalyzer"}
# {"asctime": "2024-10-18 13:57:49,370", "levelname": "INFO", "message": "Initializing BaseReader"}
# {"asctime": "2024-10-18 13:57:49,386", "levelname": "INFO", "message": "Initializing FaceDetector"}
# {"asctime": "2024-10-18 13:57:49,652", "levelname": "INFO", "message": "Initializing FaceUnifier"}
# {"asctime": "2024-10-18 13:57:49,667", "levelname": "INFO", "message": "Initializing FacePredictor objects"}
# {"asctime": "2024-10-18 13:57:49,668", "levelname": "INFO", "message": "Initializing FacePredictor embed"}
# {"asctime": "2024-10-18 13:57:49,890", "levelname": "INFO", "message": "Initializing FacePredictor verify"}
# {"asctime": "2024-10-18 13:57:51,177", "levelname": "INFO", "message": "Initializing FacePredictor au"}
# {"asctime": "2024-10-18 13:57:51,755", "levelname": "INFO", "message": "Initializing FacePredictor va"}
# {"asctime": "2024-10-18 13:57:51,794", "levelname": "INFO", "message": "Initializing FacePredictor align"}
